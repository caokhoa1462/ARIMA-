# %% [markdown]
# # **PM2.5**

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/ARIMA/city_day.csv')
df.dropna()
# Out:
#                 City        Date  PM2.5    PM10    NO    NO2    NOx    NH3  \
# 2123       Amaravati  2017-11-25  81.40  124.50  1.44  20.50  12.08  10.72
# 2124       Amaravati  2017-11-26  78.32  129.06  1.26  26.00  14.85  10.28
# 2125       Amaravati  2017-11-27  88.76  135.32  6.60  30.85  21.77  12.91
# 2126       Amaravati  2017-11-28  64.18  104.09  2.56  28.07  17.01  11.42
# 2127       Amaravati  2017-11-29  72.47  114.84  5.23  23.20  16.59  12.25
# ...              ...         ...    ...     ...   ...    ...    ...    ...
# 29525  Visakhapatnam  2020-06-26   7.63   32.27  5.91  23.27  17.19  11.15
# 29526  Visakhapatnam  2020-06-27  15.02   50.94  7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38   74.09  3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91   65.73  3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64   49.97  4.05  29.26  18.80  10.03
#
# ...

# %%
# !pip install pmdarima
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
PM2_5_data = df[["PM2.5"]]
PM2_5_data.dropna(axis=0, inplace=True)
PM2_5_data = PM2_5_data.reset_index(drop=True)
# Out:
# <ipython-input-73-43c4590894b8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PM2_5_data.dropna(axis=0, inplace=True)

# %%
PM2_5_data
print(PM2_5_data)
# Out:
#         PM2.5
# 0       73.24
# 1       83.13
# 2       79.84
# 3       94.52
# 4      135.99
# ...       ...
# 24928   15.02
# 24929   24.38
# 24930   22.91
# 24931   16.64
# 24932   15.00
#
# [24933 rows x 1 columns]

# %%
train_size = int(0.7 * len(PM2_5_data))
test_size = int(0.2 * len(PM2_5_data))

train_data = PM2_5_data[:train_size]
test_data = PM2_5_data[train_size:train_size+test_size]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression

# %%
# 3. Quá trình Training
x_train = np.array(train_data.index).reshape(-1, 1)
y_train = np.array(train_data['PM2.5'])

# Find the best ARIMA model using auto_arima
from pmdarima.arima import auto_arima
model = auto_arima(y_train, trace=True, error_action='ignore', suppress_warnings=True)

# Fit the model
model.fit(y_train)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=174226.108, Time=37.74 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=178303.075, Time=1.40 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=176790.002, Time=1.89 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=175653.972, Time=7.26 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=178301.075, Time=0.44 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=174304.297, Time=27.51 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=174305.173, Time=31.59 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=174226.558, Time=40.35 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=174226.211, Time=42.60 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=174319.966, Time=15.38 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=174303.923, Time=39.89 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=174305.761, Time=35.13 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=174226.095, Time=81.64 sec
# ...

# %%
# 4. Quá trình testing
x_test = np.array(test_data.index).reshape(-1, 1)
y_test = np.array(test_data['PM2.5'])
y_pred = model.predict(n_periods=len(y_test))
y_pred
print(y_pred)
# Out:
# [38.94470481 50.19285156 43.79027629 ... 49.52181848 49.52181848
#  49.52181848]

# %%
# 6. Quá trình tạo index predict 30 ngày tiếp theo
last_index =  PM2_5_data.index[-1]
last_data = pd.RangeIndex(start=last_index, stop=last_index+30, step=1)

# Create an array of 30 consecutive integers starting from last_index
x_next_30_days = np.array(range(last_index+1, last_index+31)).reshape(-1, 1)

# Predict the closing prices for the next 30 days
y_next_30_days = model.predict(n_periods=len(x_next_30_days))

# Print the predicted closing prices for the next 30 days
print('Predicted closing prices for the next 30 days:')
print(y_next_30_days)
# Out:
# Predicted closing prices for the next 30 days:
# [38.94470481 50.19285156 43.79027629 51.96726826 45.31186462 52.5620715
#  45.95298607 52.6347661  46.2875757  52.54585792 46.51137944 52.40808758
#  46.69176714 52.25969677 46.85174781 52.11327591 46.9994218  51.97277857
#  47.1378228  51.83925436 47.26825582 51.71278666 47.39142608 51.59314701
#  47.5078216  51.48001551 47.61784329 51.37305459 47.72184977 51.27193327]

# %%
from statsmodels.tsa.stattools import adfuller
result = adfuller(PM2_5_data)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -10.902344
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567

# %% [markdown]
# # **PM10**

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/ARIMA/city_day.csv')
df.dropna()
# Out:
#                 City        Date  PM2.5    PM10    NO    NO2    NOx    NH3  \
# 2123       Amaravati  2017-11-25  81.40  124.50  1.44  20.50  12.08  10.72
# 2124       Amaravati  2017-11-26  78.32  129.06  1.26  26.00  14.85  10.28
# 2125       Amaravati  2017-11-27  88.76  135.32  6.60  30.85  21.77  12.91
# 2126       Amaravati  2017-11-28  64.18  104.09  2.56  28.07  17.01  11.42
# 2127       Amaravati  2017-11-29  72.47  114.84  5.23  23.20  16.59  12.25
# ...              ...         ...    ...     ...   ...    ...    ...    ...
# 29525  Visakhapatnam  2020-06-26   7.63   32.27  5.91  23.27  17.19  11.15
# 29526  Visakhapatnam  2020-06-27  15.02   50.94  7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38   74.09  3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91   65.73  3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64   49.97  4.05  29.26  18.80  10.03
#
# ...

# %%
# !pip install pmdarima
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
PM10_data = df[["PM10"]]
PM10_data.dropna(axis=0, inplace=True)
PM10_data = PM10_data.reset_index(drop=True)
print(PM10_data)
# Out:
#          PM10
# 0      141.54
# 1      122.41
# 2      116.32
# 3      130.07
# 4      138.31
# ...       ...
# 18386   50.94
# 18387   74.09
# 18388   65.73
# 18389   49.97
# 18390   66.00
#
# [18391 rows x 1 columns]
# <ipython-input-29-c6ede761c144>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PM10_data.dropna(axis=0, inplace=True)

# %%
train_size = int(0.7 * len(PM10_data))
test_size = int(0.2 * len(PM10_data))

train_data = PM10_data[:train_size]
test_data = PM10_data[train_size:train_size+test_size]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression

# %%
# 3. Quá trình Training
x_train = np.array(train_data.index).reshape(-1, 1)
y_train = np.array(train_data['PM10'])

# Find the best ARIMA model using auto_arima
from pmdarima.arima import auto_arima
model = auto_arima(y_train, trace=True, error_action='ignore', suppress_warnings=True)

# Fit the model
model.fit(y_train)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=134950.672, Time=32.85 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=137179.644, Time=1.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=136624.682, Time=1.68 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=136193.830, Time=8.88 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=137177.645, Time=0.42 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=134954.607, Time=20.18 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=134955.570, Time=17.13 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=134949.971, Time=44.61 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=134949.760, Time=23.70 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=135843.056, Time=2.28 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=134946.922, Time=32.48 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=135671.567, Time=3.03 sec
#  ARIMA(5,1,1)(0,0,0)[0] intercept   : AIC=134944.104, Time=37.47 sec
# ...

# %%
# 4. Quá trình testing
x_test = np.array(test_data.index).reshape(-1, 1)
y_test = np.array(test_data['PM10'])
y_pred = model.predict(n_periods=len(y_test))
y_pred
print(y_pred)
# Out:
# [ 93.11843773 101.51079342 103.93219436 ... 106.40021242 106.40021242
#  106.40021242]

# %%
# 5. Quá trình tạo index predict 30 ngày tiếp theo
last_index =  PM10_data.index[-1]
last_data = pd.RangeIndex(start=last_index, stop=last_index+30, step=1)

# Create an array of 30 consecutive integers starting from last_index
x_next_30_days = np.array(range(last_index+1, last_index+31)).reshape(-1, 1)

# Predict the closing prices for the next 30 days
y_next_30_days = model.predict(n_periods=len(x_next_30_days))

# Print the predicted closing prices for the next 30 days
print('Predicted closing prices for the next 30 days:')
print(y_next_30_days)
# Out:
# Predicted closing prices for the next 30 days:
# [ 93.11843773 101.51079342 103.93219436 105.53410531 106.68048615
#  106.86997555 106.75424225 106.64386726 106.54442037 106.4648549
#  106.42076388 106.40166152 106.39472798 106.39379105 106.39536218
#  106.39726073 106.39869342 106.39958977 106.40006334 106.40026054
#  106.40031132 106.40030055 106.40027241 106.40024627 106.40022818
#  106.40021781 106.40021289 106.40021113 106.40021092 106.40021126]

# %%
from statsmodels.tsa.stattools import adfuller
result = adfuller(PM10_data)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -9.677054
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567

# %% [markdown]
# # **NO**

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/ARIMA/city_day.csv')
df.dropna()
# Out:
#                 City        Date  PM2.5    PM10    NO    NO2    NOx    NH3  \
# 2123       Amaravati  2017-11-25  81.40  124.50  1.44  20.50  12.08  10.72
# 2124       Amaravati  2017-11-26  78.32  129.06  1.26  26.00  14.85  10.28
# 2125       Amaravati  2017-11-27  88.76  135.32  6.60  30.85  21.77  12.91
# 2126       Amaravati  2017-11-28  64.18  104.09  2.56  28.07  17.01  11.42
# 2127       Amaravati  2017-11-29  72.47  114.84  5.23  23.20  16.59  12.25
# ...              ...         ...    ...     ...   ...    ...    ...    ...
# 29525  Visakhapatnam  2020-06-26   7.63   32.27  5.91  23.27  17.19  11.15
# 29526  Visakhapatnam  2020-06-27  15.02   50.94  7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38   74.09  3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91   65.73  3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64   49.97  4.05  29.26  18.80  10.03
#
# ...

# %%
# !pip install pmdarima
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
NO_data = df[["NO"]]
NO_data.dropna(axis=0, inplace=True)
NO_data = NO_data.reset_index(drop=True)
print(NO_data)
# Out:
#           NO
# 0       0.92
# 1       0.97
# 2      17.40
# 3       1.70
# 4      22.10
# ...      ...
# 25944   7.68
# 25945   3.42
# 25946   3.45
# 25947   4.05
# 25948   0.40
#
# [25949 rows x 1 columns]
# <ipython-input-51-c550f88acd8f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NO_data.dropna(axis=0, inplace=True)

# %%
from statsmodels.tsa.stattools import adfuller
result = adfuller(NO_data)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -10.556302
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567

# %%
train_size = int(0.7 * len(NO_data))
test_size = int(0.2 * len(NO_data))
train_data = NO_data[:train_size]
test_data = NO_data[train_size:train_size+test_size]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression

# %%
# 3. Quá trình Training
x_train = np.array(train_data.index).reshape(-1, 1)
y_train = np.array(train_data['NO'])

# Find the best ARIMA model using auto_arima
from pmdarima.arima import auto_arima
model = auto_arima(y_train, trace=True, error_action='ignore', suppress_warnings=True)

# Fit the model
model.fit(y_train)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=143288.336, Time=42.04 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=146499.500, Time=1.45 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=145855.690, Time=2.14 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=145360.751, Time=4.72 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=146497.500, Time=0.34 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=143286.633, Time=17.86 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=143988.919, Time=8.53 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=143303.050, Time=11.48 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=143287.671, Time=22.87 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=143450.828, Time=12.38 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=143287.277, Time=14.24 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=143273.882, Time=60.13 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=143273.930, Time=32.31 sec
# ...

# %%
# 4. Quá trình testing
x_test = np.array(test_data.index).reshape(-1, 1)
y_test = np.array(test_data['NO'])
y_pred = model.predict(n_periods=len(y_test))
y_pred
print(y_pred)
# Out:
# [ 7.10359584  8.36987359  9.01088082 ... 10.0177497  10.0177497
#  10.0177497 ]

# %%
# 5. Quá trình tạo index predict 30 ngày tiếp theo
last_index =  NO_data.index[-1]
last_data = pd.RangeIndex(start=last_index, stop=last_index+30, step=1)

# Create an array of 30 consecutive integers starting from last_index
x_next_30_days = np.array(range(last_index+1, last_index+31)).reshape(-1, 1)

# Predict the closing prices for the next 30 days
y_next_30_days = model.predict(n_periods=len(x_next_30_days))

# Print the predicted closing prices for the next 30 days
print('Predicted closing prices for the next 30 days:')
print(y_next_30_days)
# Out:
# Predicted closing prices for the next 30 days:
# [ 7.10359584  8.36987359  9.01088082  9.35250504  9.58998415  9.73157693
#   9.83708296  9.89363598  9.94242403  9.96300835  9.98724635  9.99278609
#  10.00623977 10.00564226 10.01421653 10.01126007 10.01750073 10.01377561
#  10.01879185 10.0149561  10.01924172 10.01555709 10.01934132 10.01590205
#  10.01929951 10.01612989 10.01920477 10.01630059 10.01909423 10.01644041]

# %% [markdown]
# # **NO2**

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/ARIMA/city_day.csv')
df.dropna()
# Out:
#                 City        Date  PM2.5    PM10    NO    NO2    NOx    NH3  \
# 2123       Amaravati  2017-11-25  81.40  124.50  1.44  20.50  12.08  10.72
# 2124       Amaravati  2017-11-26  78.32  129.06  1.26  26.00  14.85  10.28
# 2125       Amaravati  2017-11-27  88.76  135.32  6.60  30.85  21.77  12.91
# 2126       Amaravati  2017-11-28  64.18  104.09  2.56  28.07  17.01  11.42
# 2127       Amaravati  2017-11-29  72.47  114.84  5.23  23.20  16.59  12.25
# ...              ...         ...    ...     ...   ...    ...    ...    ...
# 29525  Visakhapatnam  2020-06-26   7.63   32.27  5.91  23.27  17.19  11.15
# 29526  Visakhapatnam  2020-06-27  15.02   50.94  7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38   74.09  3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91   65.73  3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64   49.97  4.05  29.26  18.80  10.03
#
# ...

# %%
# !pip install pmdarima
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#1. Loại bỏ các cột không có dữ liệu
NO2_data = df[["NO2"]]
NO2_data.dropna(axis=0, inplace=True)
NO2_data = NO2_data.reset_index(drop=True)
print(NO2_data)
# Out:
#          NO2
# 0      18.22
# 1      15.69
# 2      19.30
# 3      18.48
# 4      21.42
# ...      ...
# 25941  25.06
# 25942  26.06
# 25943  29.53
# 25944  29.26
# 25945  26.85
#
# [25946 rows x 1 columns]
# <ipython-input-62-9b35cd1c8d83>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NO2_data.dropna(axis=0, inplace=True)

# %%
#2. Xét xem chuỗi có tính dừng hay không
from statsmodels.tsa.stattools import adfuller
result = adfuller(NO2_data)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -10.304353
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567

# %%
#3. Tách dữ liệu thành 2 bên dùng để train với test
train_size = int(0.7 * len(NO2_data))
test_size = int(0.2 * len(NO2_data))
train_data = NO2_data[:train_size]
test_data = NO2_data[train_size:train_size+test_size]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression

# %%
# 4. Quá trình Training
x_train = np.array(train_data.index).reshape(-1, 1)
y_train = np.array(train_data['NO2'])
# Find the best ARIMA model using auto_arima
from pmdarima.arima import auto_arima
model = auto_arima(y_train, trace=True, error_action='ignore', suppress_warnings=True)
# Fit the model
model.fit(y_train)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=135993.469, Time=17.64 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=138880.831, Time=0.93 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=137856.040, Time=3.80 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=137214.503, Time=7.00 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=138878.833, Time=0.97 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=135989.672, Time=32.45 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=136376.738, Time=14.13 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=135990.123, Time=15.15 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=135990.719, Time=36.85 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=136085.336, Time=9.62 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=135989.731, Time=14.52 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=135993.635, Time=25.69 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=135987.686, Time=6.53 sec
# ...

# %%
# 5. Quá trình testing
x_test = np.array(test_data.index).reshape(-1, 1)
y_test = np.array(test_data['NO2'])
y_pred = model.predict(n_periods=len(y_test))
print(y_pred)
# Out:
# [76.57176923 72.21863847 69.84974491 ... 67.02162707 67.02162707
#  67.02162707]

# %%
# 6. Quá trình tạo index predict 30 ngày tiếp theo
last_index =  NO2_data.index[-1]
last_data = pd.RangeIndex(start=last_index, stop=last_index+30, step=1)

# Create an array of 30 consecutive integers starting from last_index
x_next_30_days = np.array(range(last_index+1, last_index+31)).reshape(-1, 1)

# Predict the closing prices for the next 30 days
y_next_30_days = model.predict(n_periods=len(x_next_30_days))

# Print the predicted closing prices for the next 30 days
print('Predicted closing prices for the next 30 days:')
print(y_next_30_days)
# Out:
# Predicted closing prices for the next 30 days:
# [76.57176923 72.21863847 69.84974491 68.56063669 67.85912775 67.47737951
#  67.26963915 67.15659067 67.09507178 67.06159433 67.04337651 67.03346272
#  67.02806781 67.025132   67.02353439 67.022665   67.02219189 67.02193444
#  67.02179433 67.02171809 67.0216766  67.02165402 67.02164174 67.02163505
#  67.02163141 67.02162943 67.02162836 67.02162777 67.02162745 67.02162728]

# %% [markdown]
# # **NOx**

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/ARIMA/city_day.csv')
df.dropna()
# Out:
#                 City        Date  PM2.5    PM10    NO    NO2    NOx    NH3  \
# 2123       Amaravati  2017-11-25  81.40  124.50  1.44  20.50  12.08  10.72
# 2124       Amaravati  2017-11-26  78.32  129.06  1.26  26.00  14.85  10.28
# 2125       Amaravati  2017-11-27  88.76  135.32  6.60  30.85  21.77  12.91
# 2126       Amaravati  2017-11-28  64.18  104.09  2.56  28.07  17.01  11.42
# 2127       Amaravati  2017-11-29  72.47  114.84  5.23  23.20  16.59  12.25
# ...              ...         ...    ...     ...   ...    ...    ...    ...
# 29525  Visakhapatnam  2020-06-26   7.63   32.27  5.91  23.27  17.19  11.15
# 29526  Visakhapatnam  2020-06-27  15.02   50.94  7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38   74.09  3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91   65.73  3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64   49.97  4.05  29.26  18.80  10.03
#
# ...

# %%
# !pip install pmdarima
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#1. Loại bỏ các cột không có dữ liệu
NOx_data = df[["NOx"]]
NOx_data.dropna(axis=0, inplace=True)
NOx_data = NOx_data.reset_index(drop=True)
print(NOx_data)
# Out:
#          NOx
# 0      17.15
# 1      16.46
# 2      29.70
# 3      17.97
# 4      37.76
# ...      ...
# 25341  19.54
# 25342  16.53
# 25343  18.33
# 25344  18.80
# 25345  14.05
#
# [25346 rows x 1 columns]
# <ipython-input-90-1dd22b3d71d4>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NOx_data.dropna(axis=0, inplace=True)

# %%
#2. Xét xem chuỗi có tính dừng hay không
from statsmodels.tsa.stattools import adfuller
result = adfuller(NOx_data)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -10.064096
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567

# %%
#3. Tách dữ liệu thành 2 bên dùng để train với test
train_size = int(0.7 * len(NOx_data))
test_size = int(0.2 * len(NOx_data))
train_data = NOx_data[:train_size]
test_data = NOx_data[train_size:train_size+test_size]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression

# %%
# 4. Quá trình Training
x_train = np.array(train_data.index).reshape(-1, 1)
y_train = np.array(train_data['NOx'])
# Find the best ARIMA model using auto_arima
from pmdarima.arima import auto_arima
model = auto_arima(y_train, trace=True, error_action='ignore', suppress_warnings=True)
# Fit the model
model.fit(y_train)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=143725.333, Time=46.98 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=146379.061, Time=1.52 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=145867.238, Time=5.39 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=145566.899, Time=9.80 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=146377.061, Time=1.00 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=143709.668, Time=29.93 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=144482.845, Time=13.58 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=143731.323, Time=20.83 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=143668.735, Time=25.59 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=143724.234, Time=16.31 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=143638.243, Time=36.63 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=143626.742, Time=51.97 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=143648.294, Time=33.13 sec
# ...

# %%
# 5. Quá trình testing
x_test = np.array(test_data.index).reshape(-1, 1)
y_test = np.array(test_data['NOx'])
y_pred = model.predict(n_periods=len(y_test))
y_pred
print(y_pred)
# Out:
# [30.12454808 31.35138102 34.24527051 ... 34.61723608 34.61723608
#  34.61723608]

# %%
# 6. Quá trình tạo index predict 30 ngày tiếp theo
last_index =  NOx_data.index[-1]
last_data = pd.RangeIndex(start=last_index, stop=last_index+30, step=1)

# Create an array of 30 consecutive integers starting from last_index
x_next_30_days = np.array(range(last_index+1, last_index+31)).reshape(-1, 1)

# Predict the closing prices for the next 30 days
y_next_30_days = model.predict(n_periods=len(x_next_30_days))

# Print the predicted closing prices for the next 30 days
print('Predicted closing prices for the next 30 days:')
print(y_next_30_days)
# Out:
# Predicted closing prices for the next 30 days:
# [30.12454808 31.35138102 34.24527051 33.49267091 34.4957505  34.63560361
#  34.23101754 34.90586751 34.39040909 34.67213431 34.67445861 34.49088229
#  34.7414121  34.53469298 34.64127392 34.64097099 34.56862783 34.66591885
#  34.58527641 34.6266269  34.62655554 34.59830199 34.63620576 34.60480611
#  34.6208775  34.62088187 34.60985438 34.62462465 34.61240023 34.61864732]

# %% [markdown]
# # **NH3**

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/ARIMA/city_day.csv')
df.dropna()
# Out:
#                 City        Date  PM2.5    PM10    NO    NO2    NOx    NH3  \
# 2123       Amaravati  2017-11-25  81.40  124.50  1.44  20.50  12.08  10.72
# 2124       Amaravati  2017-11-26  78.32  129.06  1.26  26.00  14.85  10.28
# 2125       Amaravati  2017-11-27  88.76  135.32  6.60  30.85  21.77  12.91
# 2126       Amaravati  2017-11-28  64.18  104.09  2.56  28.07  17.01  11.42
# 2127       Amaravati  2017-11-29  72.47  114.84  5.23  23.20  16.59  12.25
# ...              ...         ...    ...     ...   ...    ...    ...    ...
# 29525  Visakhapatnam  2020-06-26   7.63   32.27  5.91  23.27  17.19  11.15
# 29526  Visakhapatnam  2020-06-27  15.02   50.94  7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38   74.09  3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91   65.73  3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64   49.97  4.05  29.26  18.80  10.03
#
# ...

# %%
# !pip install pmdarima
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#1. Loại bỏ các cột không có dữ liệu
NH3_data = df[["NH3"]]
NH3_data.dropna(axis=0, inplace=True)
NH3_data = NH3_data.reset_index(drop=True)
print(NH3_data)
# Out:
#          NH3
# 0      26.64
# 1      25.63
# 2      29.16
# 3      28.95
# 4      28.41
# ...      ...
# 19198  12.47
# 19199  11.99
# 19200  10.71
# 19201  10.03
# 19202   5.20
#
# [19203 rows x 1 columns]
# <ipython-input-99-36a4bdefccad>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NH3_data.dropna(axis=0, inplace=True)

# %%
#2. Xét xem chuỗi có tính dừng hay không
from statsmodels.tsa.stattools import adfuller
result = adfuller(NH3_data)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -8.578070
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567

# %%
#3. Tách dữ liệu thành 2 bên dùng để train với test
train_size = int(0.7 * len(NH3_data))
test_size = int(0.2 * len(NH3_data))
train_data = NH3_data[:train_size]
test_data = NH3_data[train_size:train_size+test_size]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression

# %%
# 4. Quá trình Training
x_train = np.array(train_data.index).reshape(-1, 1)
y_train = np.array(train_data['NH3'])
# Find the best ARIMA model using auto_arima
from pmdarima.arima import auto_arima
model = auto_arima(y_train, trace=True, error_action='ignore', suppress_warnings=True)
# Fit the model
model.fit(y_train)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=104184.377, Time=21.37 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=105989.748, Time=0.75 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=105332.432, Time=1.69 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=104953.914, Time=6.21 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=105987.748, Time=0.33 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=104188.306, Time=17.38 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=104188.396, Time=36.87 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=104183.606, Time=25.23 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=104190.099, Time=17.04 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=104081.991, Time=53.90 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=104083.872, Time=27.91 sec
#  ARIMA(5,1,2)(0,0,0)[0] intercept   : AIC=104048.108, Time=67.20 sec
#  ARIMA(5,1,1)(0,0,0)[0] intercept   : AIC=104080.910, Time=42.84 sec
# ...

# %%
# 5. Quá trình testing
x_test = np.array(test_data.index).reshape(-1, 1)
y_test = np.array(test_data['NH3'])
y_pred = model.predict(n_periods=len(y_test))
y_pred
print(y_pred)
# Out:
# [3.48074684 4.19231283 4.74669888 ... 6.30519085 6.30519085 6.30519085]

# %%
# 6. Quá trình tạo index predict 30 ngày tiếp theo
last_index =  NH3_data.index[-1]
last_data = pd.RangeIndex(start=last_index, stop=last_index+30, step=1)

# Create an array of 30 consecutive integers starting from last_index
x_next_30_days = np.array(range(last_index+1, last_index+31)).reshape(-1, 1)

# Predict the closing prices for the next 30 days
y_next_30_days = model.predict(n_periods=len(x_next_30_days))

# Print the predicted closing prices for the next 30 days
print('Predicted closing prices for the next 30 days:')
print(y_next_30_days)
# Out:
# Predicted closing prices for the next 30 days:
# [3.48074684 4.19231283 4.74669888 4.96800354 5.20411692 5.50833774
#  5.61351702 5.81446368 5.86355546 5.99369039 6.03493323 6.10315185
#  6.14151882 6.17302133 6.20632779 6.21978293 6.24435999 6.25120612
#  6.26674181 6.27189359 6.28032595 6.284985   6.28898707 6.2929466
#  6.29472725 6.29765834 6.29856955 6.30044154 6.30109442 6.30213094]

# %% [markdown]
# # **CO**

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/ARIMA/city_day.csv')
df.dropna()
# Out:
#                 City        Date  PM2.5    PM10    NO    NO2    NOx    NH3  \
# 2123       Amaravati  2017-11-25  81.40  124.50  1.44  20.50  12.08  10.72
# 2124       Amaravati  2017-11-26  78.32  129.06  1.26  26.00  14.85  10.28
# 2125       Amaravati  2017-11-27  88.76  135.32  6.60  30.85  21.77  12.91
# 2126       Amaravati  2017-11-28  64.18  104.09  2.56  28.07  17.01  11.42
# 2127       Amaravati  2017-11-29  72.47  114.84  5.23  23.20  16.59  12.25
# ...              ...         ...    ...     ...   ...    ...    ...    ...
# 29525  Visakhapatnam  2020-06-26   7.63   32.27  5.91  23.27  17.19  11.15
# 29526  Visakhapatnam  2020-06-27  15.02   50.94  7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38   74.09  3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91   65.73  3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64   49.97  4.05  29.26  18.80  10.03
#
# ...

# %%
# !pip install pmdarima
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#1. Loại bỏ các cột không có dữ liệu
CO_data = df[["CO"]]
CO_data.dropna(axis=0, inplace=True)
CO_data = CO_data.reset_index(drop=True)
print(CO_data)
# Out:
#           CO
# 0       0.92
# 1       0.97
# 2      17.40
# 3       1.70
# 4      22.10
# ...      ...
# 27467   0.47
# 27468   0.52
# 27469   0.48
# 27470   0.52
# 27471   0.59
#
# [27472 rows x 1 columns]
# <ipython-input-108-12b0344c5ea0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CO_data.dropna(axis=0, inplace=True)

# %%
#2. Xét xem chuỗi có tính dừng hay không
from statsmodels.tsa.stattools import adfuller
result = adfuller(CO_data)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -7.542274
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567

# %%
#3. Tách dữ liệu thành 2 bên dùng để train với test
train_size = int(0.7 * len(CO_data))
test_size = int(0.2 * len(CO_data))
train_data = CO_data[:train_size]
test_data = CO_data[train_size:train_size+test_size]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression

# %%
# 4. Quá trình Training
x_train = np.array(train_data.index).reshape(-1, 1)
y_train = np.array(train_data['CO'])
# Find the best ARIMA model using auto_arima
from pmdarima.arima import auto_arima
model = auto_arima(y_train, trace=True, error_action='ignore', suppress_warnings=True)
# Fit the model
model.fit(y_train)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=112857.341, Time=44.24 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=117507.596, Time=1.90 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=116265.889, Time=3.90 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=115055.769, Time=5.18 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=117505.596, Time=0.53 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=112860.934, Time=18.84 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=112860.995, Time=15.89 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=112864.896, Time=22.10 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=112829.954, Time=63.95 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=112828.495, Time=37.42 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=113017.571, Time=12.58 sec
#  ARIMA(1,1,4)(0,0,0)[0] intercept   : AIC=112829.667, Time=40.30 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=113360.988, Time=6.94 sec
# ...

# %%
# 5. Quá trình testing
x_test = np.array(test_data.index).reshape(-1, 1)
y_test = np.array(test_data['CO'])
y_pred = model.predict(n_periods=len(y_test))
y_pred
print(y_pred)
# Out:
# [1.55517517 1.47956185 1.45535743 ... 1.40902608 1.40902608 1.40902608]

# %%
# 6. Quá trình tạo index predict 30 ngày tiếp theo
last_index =  CO_data.index[-1]
last_data = pd.RangeIndex(start=last_index, stop=last_index+30, step=1)

# Create an array of 30 consecutive integers starting from last_index
x_next_30_days = np.array(range(last_index+1, last_index+31)).reshape(-1, 1)

# Predict the closing prices for the next 30 days
y_next_30_days = model.predict(n_periods=len(x_next_30_days))

# Print the predicted closing prices for the next 30 days
print('Predicted closing prices for the next 30 days:')
print(y_next_30_days)
# Out:
# Predicted closing prices for the next 30 days:
# [1.55517517 1.47956185 1.45535743 1.43945878 1.42901577 1.42215629
#  1.41765064 1.41469112 1.41274715 1.41147027 1.41063154 1.41008063
#  1.40971876 1.40948107 1.40932494 1.40922239 1.40915502 1.40911078
#  1.40908172 1.40906263 1.40905009 1.40904185 1.40903644 1.40903289
#  1.40903055 1.40902902 1.40902801 1.40902735 1.40902692 1.40902663]

# %% [markdown]
# # **SO2**

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/ARIMA/city_day.csv')
df.dropna()
# Out:
#                 City        Date  PM2.5    PM10    NO    NO2    NOx    NH3  \
# 2123       Amaravati  2017-11-25  81.40  124.50  1.44  20.50  12.08  10.72
# 2124       Amaravati  2017-11-26  78.32  129.06  1.26  26.00  14.85  10.28
# 2125       Amaravati  2017-11-27  88.76  135.32  6.60  30.85  21.77  12.91
# 2126       Amaravati  2017-11-28  64.18  104.09  2.56  28.07  17.01  11.42
# 2127       Amaravati  2017-11-29  72.47  114.84  5.23  23.20  16.59  12.25
# ...              ...         ...    ...     ...   ...    ...    ...    ...
# 29525  Visakhapatnam  2020-06-26   7.63   32.27  5.91  23.27  17.19  11.15
# 29526  Visakhapatnam  2020-06-27  15.02   50.94  7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38   74.09  3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91   65.73  3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64   49.97  4.05  29.26  18.80  10.03
#
# ...

# %%
# !pip install pmdarima
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#1. Loại bỏ các cột không có dữ liệu
SO2_data = df[["SO2"]]
SO2_data.dropna(axis=0, inplace=True)
SO2_data = SO2_data.reset_index(drop=True)
print(SO2_data)
# Out:
#          SO2
# 0      27.64
# 1      24.55
# 2      29.07
# 3      18.59
# 4      39.33
# ...      ...
# 25672   8.55
# 25673  12.72
# 25674   8.42
# 25675   9.84
# 25676   2.10
#
# [25677 rows x 1 columns]
# <ipython-input-117-50a6861ac6ee>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SO2_data.dropna(axis=0, inplace=True)

# %%
#2. Xét xem chuỗi có tính dừng hay không
from statsmodels.tsa.stattools import adfuller
result = adfuller(SO2_data)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -9.322949
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567

# %%
#3. Tách dữ liệu thành 2 bên dùng để train với test
train_size = int(0.7 * len(SO2_data))
test_size = int(0.2 * len(SO2_data))
train_data = SO2_data[:train_size]
test_data = SO2_data[train_size:train_size+test_size]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression

# %%
# 4. Quá trình Training
x_train = np.array(train_data.index).reshape(-1, 1)
y_train = np.array(train_data['SO2'])
# Find the best ARIMA model using auto_arima
from pmdarima.arima import auto_arima
model = auto_arima(y_train, trace=True, error_action='ignore', suppress_warnings=True)
# Fit the model
model.fit(y_train)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=121630.540, Time=25.82 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=124795.793, Time=0.94 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=123434.141, Time=2.02 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=122588.470, Time=5.94 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=124793.793, Time=0.44 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=121649.930, Time=20.60 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=121650.654, Time=12.87 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=121607.073, Time=25.75 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=121649.414, Time=16.75 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=121608.850, Time=35.44 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=121598.386, Time=66.23 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=121607.558, Time=43.43 sec
#  ARIMA(4,1,3)(0,0,0)[0] intercept   : AIC=121621.469, Time=77.15 sec
# ...

# %%
# 5. Quá trình testing
x_test = np.array(test_data.index).reshape(-1, 1)
y_test = np.array(test_data['SO2'])
y_pred = model.predict(n_periods=len(y_test))
y_pred
print(y_pred)
# Out:
# [ 5.96627359  5.74590084  5.96790899 ... 26.02688314 26.03078372
#  26.0346843 ]

# %%
# 6. Quá trình tạo index predict 30 ngày tiếp theo
last_index =  SO2_data.index[-1]
last_data = pd.RangeIndex(start=last_index, stop=last_index+30, step=1)

# Create an array of 30 consecutive integers starting from last_index
x_next_30_days = np.array(range(last_index+1, last_index+31)).reshape(-1, 1)

# Predict the closing prices for the next 30 days
y_next_30_days = model.predict(n_periods=len(x_next_30_days))

# Print the predicted closing prices for the next 30 days
print('Predicted closing prices for the next 30 days:')
print(y_next_30_days)
# Out:
# Predicted closing prices for the next 30 days:
# [5.96627359 5.74590084 5.96790899 5.79721011 5.98482794 5.85054685
#  6.00013057 5.89739246 6.01294928 5.93701024 6.02423544 5.97012553
#  6.03473699 5.99773835 6.04486919 6.02084219 6.05482329 6.0403346
#  6.06466514 6.0569866  6.0743994  6.07143811 6.08400713 6.0842065
#  6.09346576 6.09570135 6.10275842 6.10624131 6.11187701 6.11607062]

# %% [markdown]
# # **O3**

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/ARIMA/city_day.csv')
df.dropna()
# Out:
#                 City        Date  PM2.5    PM10    NO    NO2    NOx    NH3  \
# 2123       Amaravati  2017-11-25  81.40  124.50  1.44  20.50  12.08  10.72
# 2124       Amaravati  2017-11-26  78.32  129.06  1.26  26.00  14.85  10.28
# 2125       Amaravati  2017-11-27  88.76  135.32  6.60  30.85  21.77  12.91
# 2126       Amaravati  2017-11-28  64.18  104.09  2.56  28.07  17.01  11.42
# 2127       Amaravati  2017-11-29  72.47  114.84  5.23  23.20  16.59  12.25
# ...              ...         ...    ...     ...   ...    ...    ...    ...
# 29525  Visakhapatnam  2020-06-26   7.63   32.27  5.91  23.27  17.19  11.15
# 29526  Visakhapatnam  2020-06-27  15.02   50.94  7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38   74.09  3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91   65.73  3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64   49.97  4.05  29.26  18.80  10.03
#
# ...

# %%
# !pip install pmdarima
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#1. Loại bỏ các cột không có dữ liệu
O3_data = df[["O3"]]
O3_data.dropna(axis=0, inplace=True)
O3_data = O3_data.reset_index(drop=True)
print(O3_data)
# Out:
#            O3
# 0      133.36
# 1       34.06
# 2       30.70
# 3       36.08
# 4       39.31
# ...       ...
# 25504   23.30
# 25505   30.14
# 25506   30.96
# 25507   28.30
# 25508   17.05
#
# [25509 rows x 1 columns]
# <ipython-input-126-587071d78465>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O3_data.dropna(axis=0, inplace=True)

# %%
#2. Xét xem chuỗi có tính dừng hay không
from statsmodels.tsa.stattools import adfuller
result = adfuller(O3_data)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -12.258317
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567

# %%
#3. Tách dữ liệu thành 2 bên dùng để train với test
train_size = int(0.7 * len(O3_data))
test_size = int(0.2 * len(O3_data))
train_data = O3_data[:train_size]
test_data = O3_data[train_size:train_size+test_size]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression

# %%
# 4. Quá trình Training
x_train = np.array(train_data.index).reshape(-1, 1)
y_train = np.array(train_data['O3'])
# Find the best ARIMA model using auto_arima
from pmdarima.arima import auto_arima
model = auto_arima(y_train, trace=True, error_action='ignore', suppress_warnings=True)
# Fit the model
model.fit(y_train)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=135713.383, Time=29.87 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=138606.802, Time=0.94 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=137596.300, Time=7.63 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=136962.541, Time=6.16 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=138604.804, Time=0.64 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=135707.395, Time=17.24 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=136124.934, Time=7.81 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=135711.348, Time=8.90 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=135701.605, Time=24.09 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=135853.535, Time=12.24 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=135711.395, Time=19.86 sec
#  ARIMA(1,1,4)(0,0,0)[0] intercept   : AIC=135694.363, Time=38.04 sec
#  ARIMA(0,1,4)(0,0,0)[0] intercept   : AIC=135771.524, Time=15.57 sec
# ...

# %%
# 5. Quá trình testing
x_test = np.array(test_data.index).reshape(-1, 1)
y_test = np.array(test_data['O3'])
y_pred = model.predict(n_periods=len(y_test))
y_pred
print(y_pred)
# Out:
# [50.74729573 47.37154899 45.67555126 ... 41.21578116 41.21578116
#  41.21578116]

# %%
# 6. Quá trình tạo index predict 30 ngày tiếp theo
last_index =  O3_data.index[-1]
last_data = pd.RangeIndex(start=last_index, stop=last_index+30, step=1)

# Create an array of 30 consecutive integers starting from last_index
x_next_30_days = np.array(range(last_index+1, last_index+31)).reshape(-1, 1)

# Predict the closing prices for the next 30 days
y_next_30_days = model.predict(n_periods=len(x_next_30_days))

# Print the predicted closing prices for the next 30 days
print('Predicted closing prices for the next 30 days:')
print(y_next_30_days)
# Out:
# Predicted closing prices for the next 30 days:
# [50.74729573 47.37154899 45.67555126 44.68925896 43.92108834 43.32280108
#  42.85682695 42.49390447 42.21124345 41.99109381 41.81963096 41.68608766
#  41.58207789 41.5010702  41.43797763 41.38883817 41.35056607 41.32075796
#  41.29754201 41.27946034 41.26537748 41.2544091  41.24586641 41.23921296
#  41.23403094 41.22999495 41.22685152 41.22440328 41.22249647 41.22101136]

# %% [markdown]
# # **BENZENE**

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/ARIMA/city_day.csv')
df.dropna()
# Out:
#                 City        Date  PM2.5    PM10    NO    NO2    NOx    NH3  \
# 2123       Amaravati  2017-11-25  81.40  124.50  1.44  20.50  12.08  10.72
# 2124       Amaravati  2017-11-26  78.32  129.06  1.26  26.00  14.85  10.28
# 2125       Amaravati  2017-11-27  88.76  135.32  6.60  30.85  21.77  12.91
# 2126       Amaravati  2017-11-28  64.18  104.09  2.56  28.07  17.01  11.42
# 2127       Amaravati  2017-11-29  72.47  114.84  5.23  23.20  16.59  12.25
# ...              ...         ...    ...     ...   ...    ...    ...    ...
# 29525  Visakhapatnam  2020-06-26   7.63   32.27  5.91  23.27  17.19  11.15
# 29526  Visakhapatnam  2020-06-27  15.02   50.94  7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38   74.09  3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91   65.73  3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64   49.97  4.05  29.26  18.80  10.03
#
# ...

# %%
# !pip install pmdarima
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#1. Loại bỏ các cột không có dữ liệu
BEN_data = df[["Benzene"]]
BEN_data.dropna(axis=0, inplace=True)
BEN_data = BEN_data.reset_index(drop=True)
print(BEN_data)
# Out:
#        Benzene
# 0         0.00
# 1         3.68
# 2         6.80
# 3         4.43
# 4         7.01
# ...        ...
# 23903     1.45
# 23904     2.24
# 23905     0.74
# 23906     0.01
# 23907     0.00
#
# [23908 rows x 1 columns]
# <ipython-input-135-56c7cc8ed993>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BEN_data.dropna(axis=0, inplace=True)

# %%
#2. Xét xem chuỗi có tính dừng hay không
from statsmodels.tsa.stattools import adfuller
result = adfuller(BEN_data)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -18.579263
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567

# %%
#3. Tách dữ liệu thành 2 bên dùng để train với test
train_size = int(0.7 * len(BEN_data))
test_size = int(0.2 * len(BEN_data))
train_data = BEN_data[:train_size]
test_data = BEN_data[train_size:train_size+test_size]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression

# %%
# 4. Quá trình Training
x_train = np.array(train_data.index).reshape(-1, 1)
y_train = np.array(train_data['Benzene'])
# Find the best ARIMA model using auto_arima
from pmdarima.arima import auto_arima
model = auto_arima(y_train, trace=True, error_action='ignore', suppress_warnings=True)
# Fit the model
model.fit(y_train)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=115275.440, Time=36.28 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=118514.582, Time=1.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=117610.774, Time=1.97 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=116850.184, Time=7.60 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=118512.582, Time=0.50 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=115245.431, Time=22.57 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=115803.790, Time=8.34 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=115279.011, Time=14.91 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=35.55 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=115676.286, Time=10.78 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=115258.715, Time=17.60 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=115070.731, Time=56.33 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=115083.135, Time=60.14 sec
# ...

# %%
# 5. Quá trình testing
x_test = np.array(test_data.index).reshape(-1, 1)
y_test = np.array(test_data['Benzene'])
y_pred = model.predict(n_periods=len(y_test))
y_pred
print(y_pred)
# Out:
# [5.14539434 4.67500749 3.99153982 ... 2.24183273 2.24183273 2.24183273]

# %%
# 6. Quá trình tạo index predict 30 ngày tiếp theo
last_index =  BEN_data.index[-1]
last_data = pd.RangeIndex(start=last_index, stop=last_index+30, step=1)

# Create an array of 30 consecutive integers starting from last_index
x_next_30_days = np.array(range(last_index+1, last_index+31)).reshape(-1, 1)

# Predict the closing prices for the next 30 days
y_next_30_days = model.predict(n_periods=len(x_next_30_days))

# Print the predicted closing prices for the next 30 days
print('Predicted closing prices for the next 30 days:')
print(y_next_30_days)
# Out:
# Predicted closing prices for the next 30 days:
# [5.14539434 4.67500749 3.99153982 3.82562065 3.38027051 3.30071982
#  2.98516831 2.95440554 2.72456071 2.72406761 2.5526609  2.57044544
#  2.43955926 2.4677025  2.36541049 2.3987468  2.31703453 2.35225959
#  2.28568241 2.32074002 2.26555072 2.29921355 2.25279334 2.28437803
#  2.24486401 2.27403898 2.24007931 2.26673599 2.23732821 2.26149536]

# %% [markdown]
# # **Toluene**

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/ARIMA/city_day.csv')
df.dropna()
# Out:
#                 City        Date  PM2.5    PM10    NO    NO2    NOx    NH3  \
# 2123       Amaravati  2017-11-25  81.40  124.50  1.44  20.50  12.08  10.72
# 2124       Amaravati  2017-11-26  78.32  129.06  1.26  26.00  14.85  10.28
# 2125       Amaravati  2017-11-27  88.76  135.32  6.60  30.85  21.77  12.91
# 2126       Amaravati  2017-11-28  64.18  104.09  2.56  28.07  17.01  11.42
# 2127       Amaravati  2017-11-29  72.47  114.84  5.23  23.20  16.59  12.25
# ...              ...         ...    ...     ...   ...    ...    ...    ...
# 29525  Visakhapatnam  2020-06-26   7.63   32.27  5.91  23.27  17.19  11.15
# 29526  Visakhapatnam  2020-06-27  15.02   50.94  7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38   74.09  3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91   65.73  3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64   49.97  4.05  29.26  18.80  10.03
#
# ...

# %%
# !pip install pmdarima
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#1. Loại bỏ các cột không có dữ liệu
TO_data = df[["Toluene"]]
TO_data.dropna(axis=0, inplace=True)
TO_data = TO_data.reset_index(drop=True)
print(TO_data)
# Out:
#        Toluene
# 0         0.02
# 1         5.50
# 2        16.40
# 3        10.14
# 4        18.89
# ...        ...
# 21485     5.37
# 21486    12.07
# 21487     2.21
# 21488     0.01
# 21489     0.00
#
# [21490 rows x 1 columns]
# <ipython-input-144-a72e88336fe3>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   TO_data.dropna(axis=0, inplace=True)

# %%
#2. Xét xem chuỗi có tính dừng hay không
from statsmodels.tsa.stattools import adfuller
result = adfuller(TO_data)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -13.357935
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567

# %%
#3. Tách dữ liệu thành 2 bên dùng để train với test
train_size = int(0.7 * len(TO_data))
test_size = int(0.2 * len(TO_data))
train_data = TO_data[:train_size]
test_data = TO_data[train_size:train_size+test_size]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression

# %%
# 4. Quá trình Training
x_train = np.array(train_data.index).reshape(-1, 1)
y_train = np.array(train_data['Toluene'])
# Find the best ARIMA model using auto_arima
from pmdarima.arima import auto_arima
model = auto_arima(y_train, trace=True, error_action='ignore', suppress_warnings=True)
# Fit the model
model.fit(y_train)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=106859.823, Time=38.28 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=109847.944, Time=0.95 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=108511.915, Time=2.07 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=107929.938, Time=8.01 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=109845.944, Time=0.49 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=106863.534, Time=20.66 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=42.22 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=106854.341, Time=18.67 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=106863.768, Time=24.34 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=106826.973, Time=55.40 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=106828.336, Time=26.38 sec
#  ARIMA(5,1,2)(0,0,0)[0] intercept   : AIC=106832.305, Time=34.23 sec
#  ARIMA(4,1,3)(0,0,0)[0] intercept   : AIC=106814.481, Time=69.78 sec
# ...

# %%
# 5. Quá trình testing
x_test = np.array(test_data.index).reshape(-1, 1)
y_test = np.array(test_data['Toluene'])
y_pred = model.predict(n_periods=len(y_test))
y_pred
print(y_pred)
# Out:
# [10.83918715 10.98381157 11.02173415 ... 11.08323328 11.08323328
#  11.08323328]

# %%
# 6. Quá trình tạo index predict 30 ngày tiếp theo
last_index =  TO_data.index[-1]
last_data = pd.RangeIndex(start=last_index, stop=last_index+30, step=1)

# Create an array of 30 consecutive integers starting from last_index
x_next_30_days = np.array(range(last_index+1, last_index+31)).reshape(-1, 1)

# Predict the closing prices for the next 30 days
y_next_30_days = model.predict(n_periods=len(x_next_30_days))

# Print the predicted closing prices for the next 30 days
print('Predicted closing prices for the next 30 days:')
print(y_next_30_days)
# Out:
# Predicted closing prices for the next 30 days:
# [10.83918715 10.98381157 11.02173415 10.9766458  11.09864481 11.01728807
#  11.07319535 11.08384419 11.04686002 11.10135745 11.06431032 11.08044481
#  11.09031265 11.0684169  11.0927371  11.07768016 11.08117297 11.08825112
#  11.07674954 11.08736698 11.08180512 11.08168811 11.08603806 11.08038639
#  11.08484666 11.08304355 11.08223358 11.08465841 11.08201655 11.08379648]

# %% [markdown]
# # **XYLENE**

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/ARIMA/city_day.csv')
df.dropna()
# Out:
#                 City        Date  PM2.5    PM10    NO    NO2    NOx    NH3  \
# 2123       Amaravati  2017-11-25  81.40  124.50  1.44  20.50  12.08  10.72
# 2124       Amaravati  2017-11-26  78.32  129.06  1.26  26.00  14.85  10.28
# 2125       Amaravati  2017-11-27  88.76  135.32  6.60  30.85  21.77  12.91
# 2126       Amaravati  2017-11-28  64.18  104.09  2.56  28.07  17.01  11.42
# 2127       Amaravati  2017-11-29  72.47  114.84  5.23  23.20  16.59  12.25
# ...              ...         ...    ...     ...   ...    ...    ...    ...
# 29525  Visakhapatnam  2020-06-26   7.63   32.27  5.91  23.27  17.19  11.15
# 29526  Visakhapatnam  2020-06-27  15.02   50.94  7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38   74.09  3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91   65.73  3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64   49.97  4.05  29.26  18.80  10.03
#
# ...

# %%
# !pip install pmdarima
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 20.2 MB/s eta 0:00:00
# ...

# %%
#1. Loại bỏ các cột không có dữ liệu
XY_data = df[["Xylene"]]
XY_data.dropna(axis=0, inplace=True)
XY_data = XY_data.reset_index(drop=True)
print(XY_data)
# Out:
#        Xylene
# 0        0.00
# 1        3.77
# 2        2.25
# 3        1.00
# 4        2.78
# ...       ...
# 11417    1.45
# 11418    0.73
# 11419    0.38
# 11420    0.00
# 11421    0.00
#
# [11422 rows x 1 columns]
# <ipython-input-3-9dd801a2aecc>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   XY_data.dropna(axis=0, inplace=True)

# %%
#2. Xét xem chuỗi có tính dừng hay không
from statsmodels.tsa.stattools import adfuller
result = adfuller(XY_data)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -9.129270
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567

# %%
#3. Tách dữ liệu thành 2 bên dùng để train với test
train_size = int(0.7 * len(XY_data))
test_size = int(0.2 * len(XY_data))
train_data = XY_data[:train_size]
test_data = XY_data[train_size:train_size+test_size]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression

# %%
# 4. Quá trình Training
x_train = np.array(train_data.index).reshape(-1, 1)
y_train = np.array(train_data['Xylene'])
# Find the best ARIMA model using auto_arima
from pmdarima.arima import auto_arima
model = auto_arima(y_train, trace=True, error_action='ignore', suppress_warnings=True)
# Fit the model
model.fit(y_train)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=45998.097, Time=6.07 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=48439.211, Time=0.19 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=47599.752, Time=0.35 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=46593.837, Time=1.66 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=48437.211, Time=0.22 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=46039.063, Time=9.63 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=46039.067, Time=7.68 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=45986.466, Time=20.03 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=46039.900, Time=9.69 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=45976.188, Time=12.99 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=46039.144, Time=10.08 sec
#  ARIMA(5,1,2)(0,0,0)[0] intercept   : AIC=45869.553, Time=16.06 sec
#  ARIMA(5,1,1)(0,0,0)[0] intercept   : AIC=45890.791, Time=16.73 sec
# ...

# %%
# 5. Quá trình testing
x_test = np.array(test_data.index).reshape(-1, 1)
y_test = np.array(test_data['Xylene'])
y_pred = model.predict(n_periods=len(y_test))
y_pred
print(y_pred)
# Out:
# [5.38962955e-13 7.61888113e-13 8.63972981e-13 ... 1.25649636e-12
#  1.25649636e-12 1.25649636e-12]

# %%
# 6. Quá trình tạo index predict 30 ngày tiếp theo
last_index =  XY_data.index[-1]
last_data = pd.RangeIndex(start=last_index, stop=last_index+30, step=1)

# Create an array of 30 consecutive integers starting from last_index
x_next_30_days = np.array(range(last_index+1, last_index+31)).reshape(-1, 1)

# Predict the closing prices for the next 30 days
y_next_30_days = model.predict(n_periods=len(x_next_30_days))

# Print the predicted closing prices for the next 30 days
print('Predicted closing prices for the next 30 days:')
print(y_next_30_days)
# Out:
# Predicted closing prices for the next 30 days:
# [5.38962955e-13 7.61888113e-13 8.63972981e-13 9.27500143e-13
#  9.57347055e-13 1.05971076e-12 1.10565356e-12 1.14268250e-12
#  1.16598370e-12 1.17997368e-12 1.20232773e-12 1.21367209e-12
#  1.22444758e-12 1.23135215e-12 1.23617275e-12 1.24153039e-12
#  1.24462227e-12 1.24757642e-12 1.24952044e-12 1.25099734e-12
#  1.25235634e-12 1.25322844e-12 1.25402536e-12 1.25456662e-12
#  1.25499478e-12 1.25535147e-12 1.25559855e-12 1.25581323e-12
#  1.25596372e-12 1.25608444e-12]
